# %%
from scipy import stats

# %%
df = pd.read_csv("/Users/guywinfield/PycharmProjects/Data-Science-Projects/Python for Data Analysis/Pandas/datasets/grades.csv")

# %%
df.head()
# Out:
#                              student_id  assignment1_grade  \
# 0  B73F2C11-70F0-E37D-8B10-1D20AFED50B1          92.733946
# 1  98A0FAE0-A19A-13D2-4BB5-CFBFD94031D1          86.790821
# 2  D0F62040-CEB0-904C-F563-2F8620916C4E          85.512541
# 3  FFDF2B2C-F514-EF7F-6538-A6A53518E9DC          86.030665
# 4  5ECBEEB6-F1CE-80AE-3164-E45E99473FB4          64.813800
#
#           assignment1_submission  assignment2_grade  \
# 0  2015-11-02 06:55:34.282000000          83.030552
# 1  2015-11-29 14:57:44.429000000          86.290821
# 2  2016-01-09 05:36:02.389000000          85.512541
# 3  2016-04-30 06:50:39.801000000          68.824532
# 4  2015-12-13 17:06:10.750000000          51.491040
#
#           assignment2_submission  assignment3_grade  \
# 0  2015-11-09 02:22:58.938000000          67.164441
# 1  2015-12-06 17:41:18.449000000          69.772657
# 2  2016-01-09 06:39:44.416000000          68.410033
# 3  2016-04-30 17:20:38.727000000          61.942079
# ...

# %%
print("There are {} rows and {} columns".format(df.shape[0], df.shape[1]))
# Out:
# There are 2315 rows and 13 columns

# %%
early_finishers = df[pd.to_datetime(df['assignment1_submission']) < '2016']
early_finishers.head()
# Out:
#                              student_id  assignment1_grade  \
# 0  B73F2C11-70F0-E37D-8B10-1D20AFED50B1          92.733946
# 1  98A0FAE0-A19A-13D2-4BB5-CFBFD94031D1          86.790821
# 4  5ECBEEB6-F1CE-80AE-3164-E45E99473FB4          64.813800
# 5  D09000A0-827B-C0FF-3433-BF8FF286E15B          71.647278
# 8  C9D51293-BD58-F113-4167-A7C0BAFCB6E5          66.595568
#
#           assignment1_submission  assignment2_grade  \
# 0  2015-11-02 06:55:34.282000000          83.030552
# 1  2015-11-29 14:57:44.429000000          86.290821
# 4  2015-12-13 17:06:10.750000000          51.491040
# 5  2015-12-28 04:35:32.836000000          64.052550
# 8  2015-12-25 02:29:28.415000000          52.916454
#
#           assignment2_submission  assignment3_grade  \
# 0  2015-11-09 02:22:58.938000000          67.164441
# 1  2015-12-06 17:41:18.449000000          69.772657
# 4  2015-12-14 12:25:12.056000000          41.932832
# 5  2016-01-03 21:05:38.392000000          64.752550
# ...

# %%
late_finishers = df[~df.index.isin(early_finishers.index)]
late_finishers.head()
# Out:
#                              student_id  assignment1_grade  \
# 2  D0F62040-CEB0-904C-F563-2F8620916C4E          85.512541
# 3  FFDF2B2C-F514-EF7F-6538-A6A53518E9DC          86.030665
# 6  3217BE3F-E4B0-C3B6-9F64-462456819CE4          87.498744
# 7  F1CB5AA1-B3DE-5460-FAFF-BE951FD38B5F          80.576090
# 9  E2C617C2-4654-622C-AB50-1550C4BE42A0          59.270882
#
#           assignment1_submission  assignment2_grade  \
# 2  2016-01-09 05:36:02.389000000          85.512541
# 3  2016-04-30 06:50:39.801000000          68.824532
# 6  2016-03-05 11:05:25.408000000          69.998995
# 7  2016-01-24 18:24:25.619000000          72.518481
# 9  2016-03-06 12:06:26.185000000          59.270882
#
#           assignment2_submission  assignment3_grade  \
# 2  2016-01-09 06:39:44.416000000          68.410033
# 3  2016-04-30 17:20:38.727000000          61.942079
# 6  2016-03-09 07:29:52.405000000          55.999196
# 7  2016-01-27 13:37:12.943000000          65.266633
# ...

# %%
print(early_finishers['assignment1_grade'].mean())
print(late_finishers['assignment1_grade'].mean())
# Out:
# 74.94728457024303
# 74.0450648477065

# %%
from scipy.stats import ttest_ind

# %%
print(ttest_ind(early_finishers['assignment1_grade'], late_finishers['assignment1_grade']))
# Out:
# TtestResult(statistic=np.float64(1.3223540853721392), pvalue=np.float64(0.1861810110171454), df=np.float64(2313.0))

# %%
print(ttest_ind(early_finishers['assignment2_grade'], late_finishers['assignment2_grade']))
print(ttest_ind(early_finishers['assignment3_grade'], late_finishers['assignment3_grade']))
print(ttest_ind(early_finishers['assignment4_grade'], late_finishers['assignment4_grade']))
print(ttest_ind(early_finishers['assignment5_grade'], late_finishers['assignment5_grade']))
print(ttest_ind(early_finishers['assignment6_grade'], late_finishers['assignment6_grade']))
# Out:
# TtestResult(statistic=np.float64(1.2514717608216366), pvalue=np.float64(0.2108889627004424), df=np.float64(2313.0))
# TtestResult(statistic=np.float64(1.6133726558705392), pvalue=np.float64(0.10679998102227867), df=np.float64(2313.0))
# TtestResult(statistic=np.float64(0.049671157386456125), pvalue=np.float64(0.960388729789337), df=np.float64(2313.0))
# TtestResult(statistic=np.float64(-0.05279315545404755), pvalue=np.float64(0.9579012739746492), df=np.float64(2313.0))
# TtestResult(statistic=np.float64(-0.11609743352612056), pvalue=np.float64(0.9075854011989656), df=np.float64(2313.0))

# %%
df1 = pd.DataFrame([np.random.random(100) for _ in range(100)])
df1.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.371448  0.298530  0.736938  0.613170  0.957037  0.645959  0.927083
# 1  0.582568  0.242168  0.003396  0.538876  0.482672  0.379463  0.620014
# 2  0.548857  0.366056  0.526722  0.477153  0.605307  0.036989  0.950119
# 3  0.973525  0.030864  0.449982  0.306070  0.939606  0.026588  0.754672
# 4  0.154580  0.879257  0.028753  0.601520  0.825579  0.936710  0.248046
#
#          7         8         9   ...        90        91        92        93  \
# 0  0.229268  0.210066  0.250092  ...  0.396456  0.878653  0.342114  0.980368
# 1  0.088819  0.309831  0.380775  ...  0.465898  0.461538  0.343644  0.583114
# 2  0.633431  0.180194  0.860806  ...  0.739441  0.188675  0.239088  0.704316
# 3  0.558849  0.686300  0.853579  ...  0.107586  0.649775  0.873185  0.862016
# 4  0.251168  0.427582  0.783475  ...  0.378981  0.460831  0.656212  0.925841
#
#          94        95        96        97        98        99
# ...

# %%
df2 = pd.DataFrame([np.random.random(100) for _ in range(100)])
df2.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.479105  0.054758  0.952925  0.968418  0.643612  0.436655  0.537705
# 1  0.420784  0.471859  0.545397  0.665882  0.465145  0.350419  0.799257
# 2  0.474044  0.862557  0.251813  0.042338  0.806045  0.562986  0.220567
# 3  0.562127  0.542913  0.163843  0.626675  0.981058  0.044207  0.633992
# 4  0.644676  0.671383  0.926742  0.207823  0.682363  0.055253  0.845060
#
#          7         8         9   ...        90        91        92        93  \
# 0  0.894636  0.809783  0.660771  ...  0.294467  0.383893  0.152433  0.386323
# 1  0.748948  0.111227  0.095902  ...  0.872640  0.174084  0.592758  0.894017
# 2  0.984668  0.017510  0.376472  ...  0.075569  0.572563  0.164993  0.204028
# 3  0.222108  0.541215  0.371821  ...  0.916602  0.281597  0.018158  0.643646
# 4  0.597943  0.490719  0.685116  ...  0.920492  0.834070  0.293795  0.561123
#
#          94        95        96        97        98        99
# ...

# %%
def test_columns(alpha=0.1):
    num_diff = 0
    for col in df1.columns:
        teststat,pval = ttest_ind(df1[col],df2[col])
        if pval <= alpha:
            print("Col {} is statistically significantly different at alpha={}, pvalue={}".format(col,alpha,pval))
            num_diff += 1
    print("Total number different was {}, which is {}%".format(num_diff, float(num_diff)/len(df1.columns)*100))

# %%
test_columns()
# Out:
# Col 1 is statistically significantly different at alpha=0.1, pvalue=0.07432137341823383
# Col 9 is statistically significantly different at alpha=0.1, pvalue=0.009785450538230296
# Col 14 is statistically significantly different at alpha=0.1, pvalue=0.00476593860165532
# Col 18 is statistically significantly different at alpha=0.1, pvalue=0.00260435768985768
# Col 19 is statistically significantly different at alpha=0.1, pvalue=0.0011522944573669315
# Col 37 is statistically significantly different at alpha=0.1, pvalue=0.0529451985328519
# Col 46 is statistically significantly different at alpha=0.1, pvalue=0.04916594668843419
# Col 47 is statistically significantly different at alpha=0.1, pvalue=0.0699068874267747
# Col 59 is statistically significantly different at alpha=0.1, pvalue=0.04516073424491424
# Col 80 is statistically significantly different at alpha=0.1, pvalue=0.047750056203115135
# ...

# %%
test_columns(alpha=0.05)
# Out:
# Col 9 is statistically significantly different at alpha=0.05, pvalue=0.009785450538230296
# Col 14 is statistically significantly different at alpha=0.05, pvalue=0.00476593860165532
# Col 18 is statistically significantly different at alpha=0.05, pvalue=0.00260435768985768
# Col 19 is statistically significantly different at alpha=0.05, pvalue=0.0011522944573669315
# Col 46 is statistically significantly different at alpha=0.05, pvalue=0.04916594668843419
# Col 59 is statistically significantly different at alpha=0.05, pvalue=0.04516073424491424
# Col 80 is statistically significantly different at alpha=0.05, pvalue=0.047750056203115135
# Col 89 is statistically significantly different at alpha=0.05, pvalue=0.030104466501005324
# Total number different was 8, which is 8.0%

# %%
df2 = pd.DataFrame([np.random.chisquare(df=1,size=100) for x in range(100)])
df2.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.184166  0.001225  0.006832  1.165361  0.015793  1.170756  0.340437
# 1  0.549042  0.130295  0.004753  3.357991  1.177424  0.330137  3.285269
# 2  0.970732  0.009286  0.033723  1.309128  0.540628  0.008450  3.654520
# 3  0.302983  0.014728  0.152407  0.040409  0.002264  1.856499  0.001237
# 4  0.259268  0.128688  0.003313  1.819229  0.001149  0.053126  1.426982
#
#          7         8         9   ...        90        91        92        93  \
# 0  0.401566  0.524836  0.003268  ...  1.593256  0.070677  0.000126  0.341775
# 1  0.131870  1.149966  0.034269  ...  0.316991  0.075865  0.726111  0.000709
# 2  1.006656  0.008051  0.843296  ...  0.006187  0.745700  2.285651  0.470940
# 3  0.013922  0.149315  0.012755  ...  0.533361  2.629191  0.048562  5.140904
# 4  0.509480  0.281021  0.185855  ...  5.353824  0.008817  1.278924  0.030144
#
#          94        95        96        97        98        99
# ...

# %%
test_columns(alpha=0.05)
# Out:
# Col 0 is statistically significantly different at alpha=0.05, pvalue=0.007322873184693639
# Col 1 is statistically significantly different at alpha=0.05, pvalue=0.0023744705107821076
# Col 2 is statistically significantly different at alpha=0.05, pvalue=0.00020423005224059863
# Col 3 is statistically significantly different at alpha=0.05, pvalue=0.00027599796650670864
# Col 4 is statistically significantly different at alpha=0.05, pvalue=0.002946394647746355
# Col 5 is statistically significantly different at alpha=0.05, pvalue=5.742508219726449e-06
# Col 6 is statistically significantly different at alpha=0.05, pvalue=8.984305660717275e-06
# Col 7 is statistically significantly different at alpha=0.05, pvalue=7.098884238907414e-06
# Col 8 is statistically significantly different at alpha=0.05, pvalue=0.0006991801393972329
# Col 9 is statistically significantly different at alpha=0.05, pvalue=0.012258631980063186
# ...
