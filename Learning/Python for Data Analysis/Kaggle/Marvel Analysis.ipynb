# %%
import pandas as pd
import numpy as np
import seaborn as sns

data_raw = pd.read_csv('/Users/guywinfield/PycharmProjects/Data/marvel-wikia-data.csv')

# %%
data = data_raw.copy()

# %%
data.head()
# Out:
#    page_id                                 name  \
# 0     1678            Spider-Man (Peter Parker)
# 1     7139      Captain America (Steven Rogers)
# 2    64786  Wolverine (James \"Logan\" Howlett)
# 3     1868    Iron Man (Anthony \"Tony\" Stark)
# 4     2460                  Thor (Thor Odinson)
#
#                                    urlslug                ID  \
# 0              \/Spider-Man_(Peter_Parker)   Secret Identity
# 1        \/Captain_America_(Steven_Rogers)   Public Identity
# 2  \/Wolverine_(James_%22Logan%22_Howlett)   Public Identity
# 3    \/Iron_Man_(Anthony_%22Tony%22_Stark)   Public Identity
# 4                    \/Thor_(Thor_Odinson)  No Dual Identity
#
#                 ALIGN         EYE        HAIR              SEX  GSM  \
# 0     Good Characters  Hazel Eyes  Brown Hair  Male Characters  NaN
# 1     Good Characters   Blue Eyes  White Hair  Male Characters  NaN
# 2  Neutral Characters   Blue Eyes  Black Hair  Male Characters  NaN
# ...

# %%
print(len(data))
data.isnull().sum()/len(data)
# Out:
# 16376
# page_id             0.000000
# name                0.000000
# urlslug             0.000000
# ID                  0.230215
# ALIGN               0.171715
# EYE                 0.596422
# HAIR                0.260381
# SEX                 0.052149
# GSM                 0.994504
# ALIVE               0.000183
# APPEARANCES         0.066927
# FIRST APPEARANCE    0.049768
# Year                0.049768
# dtype: float64

# %%
data.describe()
# Out:
#              page_id   APPEARANCES          Year
# count   16376.000000  15280.000000  15561.000000
# mean   300232.082377     17.033377   1984.951803
# std    253460.403399     96.372959     19.663571
# min      1025.000000      1.000000   1939.000000
# 25%     28309.500000      1.000000   1974.000000
# 50%    282578.000000      3.000000   1990.000000
# 75%    509077.000000      8.000000   2000.000000
# max    755278.000000   4043.000000   2013.000000

# %%
sns.lineplot(data=data[''])

# %%
sns.histplot(data=data['Year'])
# Out:
# <Axes: xlabel='Year', ylabel='Count'>

# %%
sns.violinplot(data=data['APPEARANCES'])
# Out:
# <Axes: ylabel='APPEARANCES'>

# %%
sns.histplot(data=data['APPEARANCES'])
# Out:
# <Axes: xlabel='APPEARANCES', ylabel='Count'>

# %%
data[data['name'].str.contains('Spider-Man')]
# Out:
#        page_id                           name  \
# 0         1678      Spider-Man (Peter Parker)
# 10215   117593  Vern (Spider-Man) (Earth-616)
#
#                                urlslug               ID            ALIGN  \
# 0          \/Spider-Man_(Peter_Parker)  Secret Identity  Good Characters
# 10215  \/Vern_(Spider-Man)_(Earth-616)              NaN              NaN
#
#               EYE        HAIR              SEX  GSM              ALIVE  \
# 0      Hazel Eyes  Brown Hair  Male Characters  NaN  Living Characters
# 10215         NaN         NaN  Male Characters  NaN  Living Characters
#
#        APPEARANCES FIRST APPEARANCE    Year
# 0           4043.0           Aug-62  1962.0
# 10215          2.0           Jun-08  2008.0

# %%
sns.histplot(data=data[['APPEARANCES']].sort_values('APPEARANCES',ascending=False).head(100))
# Out:
# <Axes: ylabel='Count'>

# %%
df = data[data['APPEARANCES']>=100]

sns.histplot(data=df['APPEARANCES'])
# Out:
# <Axes: xlabel='APPEARANCES', ylabel='Count'>

# %%
df.describe()
# Out:
#              page_id  APPEARANCES         Year
# count     414.000000    414.00000   407.000000
# mean    13921.229469    360.00000  1973.425061
# std     49224.994614    465.43876    14.281776
# min      1025.000000    100.00000  1939.000000
# 25%      1666.500000    134.00000  1964.000000
# 50%      2155.000000    199.00000  1972.000000
# 75%      6436.250000    364.75000  1982.000000
# max    626857.000000   4043.00000  2010.000000

# %%
sns.violinplot(data=df, x='ALIGN', y='APPEARANCES')
# Out:
# <Axes: xlabel='ALIGN', ylabel='APPEARANCES'>

# %%
sns.violinplot(data=df, x='ID', y='APPEARANCES')
# Out:
# <Axes: xlabel='ID', ylabel='APPEARANCES'>

# %%
sns.violinplot(data=df, x='ALIVE', y='APPEARANCES')
# Out:
# <Axes: xlabel='ALIVE', ylabel='APPEARANCES'>

# %%
sns.violinplot(data=df, x='HAIR', y='APPEARANCES')
# Out:
# <Axes: xlabel='HAIR', ylabel='APPEARANCES'>

# %%
sns.violinplot(data=df, x='SEX', y='APPEARANCES')
# Out:
# <Axes: xlabel='SEX', ylabel='APPEARANCES'>

# %%
sns.pairplot(data=df)

# %%
sns.scatterplot(data=df, x='Year', y='APPEARANCES')
# Out:
# <Axes: xlabel='Year', ylabel='APPEARANCES'>

# %%
sns.kdeplot(data=df, x='Year', y='APPEARANCES', hue='SEX')
# Out:
# /var/folders/kn/24kjgmss2yzfjngp_zf6x8vr0000gn/T/ipykernel_17400/2527675299.py:1: UserWarning: KDE cannot be estimated (0 variance or perfect covariance). Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(data=df, x='Year', y='APPEARANCES', hue='SEX')
# /var/folders/kn/24kjgmss2yzfjngp_zf6x8vr0000gn/T/ipykernel_17400/2527675299.py:1: UserWarning: KDE cannot be estimated (0 variance or perfect covariance). Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(data=df, x='Year', y='APPEARANCES', hue='SEX')
# <Axes: xlabel='Year', ylabel='APPEARANCES'>

# %%
num_cols = ['APPEARANCES','Year','SEX']
sns.pairplot(df[num_cols], hue='SEX', palette="Set2", diag_kind="kde", size=2).map_upper(sns.kdeplot, cmap="Blues_d", height=20)
# Out:
# /Users/guywinfield/PycharmProjects/.turing_venv/lib/python3.13/site-packages/seaborn/axisgrid.py:2100: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /Users/guywinfield/PycharmProjects/.turing_venv/lib/python3.13/site-packages/seaborn/axisgrid.py:1615: UserWarning: KDE cannot be estimated (0 variance or perfect covariance). Pass `warn_singular=False` to disable this warning.
#   func(x=x, y=y, **kwargs)
# /Users/guywinfield/PycharmProjects/.turing_venv/lib/python3.13/site-packages/seaborn/axisgrid.py:1615: UserWarning: KDE cannot be estimated (0 variance or perfect covariance). Pass `warn_singular=False` to disable this warning.
#   func(x=x, y=y, **kwargs)
# /Users/guywinfield/PycharmProjects/.turing_venv/lib/python3.13/site-packages/seaborn/distributions.py:1128: UserWarning: cmap parameter ignored when using hue mapping.
#   warnings.warn(msg, UserWarning)
# ...

# %%
num_cols = ['APPEARANCES','Year','ALIGN']
sns.pairplot(df[num_cols], hue='ALIGN', palette="Set2", diag_kind="kde", size=2).map_upper(sns.kdeplot, cmap="Blues_d", height=20)
# Out:
# /Users/guywinfield/PycharmProjects/.turing_venv/lib/python3.13/site-packages/seaborn/axisgrid.py:2100: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /Users/guywinfield/PycharmProjects/.turing_venv/lib/python3.13/site-packages/seaborn/distributions.py:1128: UserWarning: cmap parameter ignored when using hue mapping.
#   warnings.warn(msg, UserWarning)
# /Users/guywinfield/PycharmProjects/.turing_venv/lib/python3.13/site-packages/seaborn/distributions.py:1176: UserWarning: The following kwargs were not used by contour: 'height'
#   cset = contour_func(

# %%
print(len(data))
data[data['APPEARANCES']<=5].count()
# Out:
# 16376
# page_id             10196
# name                10196
# urlslug             10196
# ID                   7553
# ALIGN                8302
# EYE                  2984
# HAIR                 7185
# SEX                  9577
# GSM                    16
# ALIVE               10196
# APPEARANCES         10196
# FIRST APPEARANCE     9673
# Year                 9673
# dtype: int64
