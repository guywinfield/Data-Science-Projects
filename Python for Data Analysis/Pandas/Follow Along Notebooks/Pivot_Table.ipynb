# %%
import pandas as pd
import numpy as np

df = pd.read_csv("/Users/guywinfield/PycharmProjects/Data-Science-Projects/Python for Data Analysis/Pandas/datasets/cwurData.csv")

# %%
df.head()
# Out:
#    world_rank                            institution         country  \
# 0           1                     Harvard University             USA
# 1           2  Massachusetts Institute of Technology             USA
# 2           3                    Stanford University             USA
# 3           4                University of Cambridge  United Kingdom
# 4           5     California Institute of Technology             USA
#
#    national_rank  quality_of_education  alumni_employment  quality_of_faculty  \
# 0              1                     7                  9                   1
# 1              2                     9                 17                   3
# 2              3                    17                 11                   5
# 3              1                    10                 24                   4
# 4              4                     2                 29                   7
#
#    publications  influence  citations  broad_impact  patents   score  year
# ...

# %%
def create_category(ranking):
    # Since the rank is just an integer, I'll just do a bunch of if/elif statements
    if (ranking >= 1) & (ranking <= 100):
        return "First Tier Top Unversity"
    elif (ranking >= 101) & (ranking <= 200):
        return "Second Tier Top Unversity"
    elif (ranking >= 201) & (ranking <= 300):
        return "Third Tier Top Unversity"
    return "Other Top Unversity"


df['Rank_Level'] = df['world_rank'].apply(lambda x: create_category(x))
# And lets look at the result
df.head()
# Out:
#    world_rank                            institution         country  \
# 0           1                     Harvard University             USA
# 1           2  Massachusetts Institute of Technology             USA
# 2           3                    Stanford University             USA
# 3           4                University of Cambridge  United Kingdom
# 4           5     California Institute of Technology             USA
#
#    national_rank  quality_of_education  alumni_employment  quality_of_faculty  \
# 0              1                     7                  9                   1
# 1              2                     9                 17                   3
# 2              3                    17                 11                   5
# 3              1                    10                 24                   4
# 4              4                     2                 29                   7
#
#    publications  influence  citations  broad_impact  patents   score  year  \
# ...

# %%
df.pivot_table(values="score", index="country", columns="Rank_Level", aggfunc=[np.mean]).head(10)
# Out:
# /var/folders/kn/24kjgmss2yzfjngp_zf6x8vr0000gn/T/ipykernel_8902/4226957393.py:1: FutureWarning: The provided callable <function mean at 0x1064c28b0> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df.pivot_table(values="score", index="country", columns="Rank_Level", aggfunc=[np.mean]).head(10)
#                                mean                      \
# Rank_Level First Tier Top Unversity Other Top Unversity
# country
# Argentina                       NaN           44.672857
# Australia                 47.942500           44.645750
# Austria                         NaN           44.864286
# Belgium                   51.875000           45.081000
# Brazil                          NaN           44.499706
# Bulgaria                        NaN           44.335000
# Canada                    53.633846           44.760541
# ...

# %%
df.pivot_table(values="score", index="country", columns="Rank_Level", aggfunc=[np.mean, np.max]).head(10)
# Out:
# /var/folders/kn/24kjgmss2yzfjngp_zf6x8vr0000gn/T/ipykernel_8902/1980233535.py:1: FutureWarning: The provided callable <function mean at 0x1064c28b0> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df.pivot_table(values="score", index="country", columns="Rank_Level", aggfunc=[np.mean, np.max]).head(10)
# /var/folders/kn/24kjgmss2yzfjngp_zf6x8vr0000gn/T/ipykernel_8902/1980233535.py:1: FutureWarning: The provided callable <function max at 0x1064bdf70> is currently using DataFrameGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   df.pivot_table(values="score", index="country", columns="Rank_Level", aggfunc=[np.mean, np.max]).head(10)
#                                mean                      \
# Rank_Level First Tier Top Unversity Other Top Unversity
# country
# ...

# %%
df.pivot_table(values="score", index="country", columns="Rank_Level", aggfunc=[np.mean, np.max],margins=True).head(10)
# Out:
# /var/folders/kn/24kjgmss2yzfjngp_zf6x8vr0000gn/T/ipykernel_8902/394841234.py:1: FutureWarning: The provided callable <function mean at 0x1064c28b0> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df.pivot_table(values="score", index="country", columns="Rank_Level", aggfunc=[np.mean, np.max],margins=True).head(10)
# /var/folders/kn/24kjgmss2yzfjngp_zf6x8vr0000gn/T/ipykernel_8902/394841234.py:1: FutureWarning: The provided callable <function mean at 0x1064c28b0> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df.pivot_table(values="score", index="country", columns="Rank_Level", aggfunc=[np.mean, np.max],margins=True).head(10)
# ...

# %%
new_df = df.pivot_table(values="score", index="country", columns="Rank_Level", aggfunc=[np.mean, np.max],margins=True).head(10)

new_df["mean"]["First Tier Top Unversity"].head()
# Out:
# /var/folders/kn/24kjgmss2yzfjngp_zf6x8vr0000gn/T/ipykernel_8902/3910953854.py:1: FutureWarning: The provided callable <function mean at 0x1064c28b0> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   new_df = df.pivot_table(values="score", index="country", columns="Rank_Level", aggfunc=[np.mean, np.max],margins=True).head(10)
# /var/folders/kn/24kjgmss2yzfjngp_zf6x8vr0000gn/T/ipykernel_8902/3910953854.py:1: FutureWarning: The provided callable <function mean at 0x1064c28b0> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   new_df = df.pivot_table(values="score", index="country", columns="Rank_Level", aggfunc=[np.mean, np.max],margins=True).head(10)
# ...

# %%
new_df["mean"]["First Tier Top Unversity"].idxmax()
# Out:
# 'Canada'

# %%
new_df.head()
# Out:
#                                mean                      \
# Rank_Level First Tier Top Unversity Other Top Unversity
# country
# Argentina                       NaN           44.672857
# Australia                   47.9425           44.645750
# Austria                         NaN           44.864286
# Belgium                     51.8750           45.081000
# Brazil                          NaN           44.499706
#
#                                                                           \
# Rank_Level Second Tier Top Unversity Third Tier Top Unversity        All
# country
# Argentina                        NaN                      NaN  44.672857
# Australia                    49.2425                47.285000  45.825517
# Austria                          NaN                47.066667  45.139583
# Belgium                      49.0840                46.746667  47.011000
# Brazil                       49.5650                      NaN  44.781111
#
# ...

# %%
new_df=new_df.stack()
# Out:
# /var/folders/kn/24kjgmss2yzfjngp_zf6x8vr0000gn/T/ipykernel_8902/503228558.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   new_df=new_df.stack()

# %%
new_df.head()
# Out:
#                                           mean    max
# country   Rank_Level
# Argentina Other Top Unversity        44.672857  45.66
#           All                        44.672857  45.66
# Australia First Tier Top Unversity   47.942500  51.61
#           Other Top Unversity        44.645750  45.97
#           Second Tier Top Unversity  49.242500  50.40

# %%
new_df.unstack().head()
# Out:
#                                mean                      \
# Rank_Level First Tier Top Unversity Other Top Unversity
# country
# Argentina                       NaN           44.672857
# Australia                   47.9425           44.645750
# Austria                         NaN           44.864286
# Belgium                     51.8750           45.081000
# Brazil                          NaN           44.499706
#
#                                                                           \
# Rank_Level Second Tier Top Unversity Third Tier Top Unversity        All
# country
# Argentina                        NaN                      NaN  44.672857
# Australia                    49.2425                47.285000  45.825517
# Austria                          NaN                47.066667  45.139583
# Belgium                      49.0840                46.746667  47.011000
# Brazil                       49.5650                      NaN  44.781111
#
# ...

# %%
new_df.unstack().unstack().head()
# Out:
#       Rank_Level                country
# mean  First Tier Top Unversity  Argentina        NaN
#                                 Australia    47.9425
#                                 Austria          NaN
#                                 Belgium      51.8750
#                                 Brazil           NaN
# dtype: float64
